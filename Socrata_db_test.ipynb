# %%
from sodapy import Socrata
import urllib3
from pathlib import Path

# %%
client = Socrata("sandbox.demo.socrata.com", "SOCRATA_PUBLIC_TOKEN")

# %%
client.datasets()
# Out:
# [{'resource': {'name': 'World of Data',
#    'id': 'p4nn-nexg',
#    'parent_fxf': None,
#    'description': '',
#    'attribution': None,
#    'attribution_link': None,
#    'contact_email': None,
#    'type': 'story',
#    'updatedAt': '2019-11-01T15:52:19.600Z',
#    'createdAt': '2019-08-16T21:11:32.000Z',
#    'metadata_updated_at': '2019-10-29T20:24:37.000Z',
#    'data_updated_at': '2019-08-16T21:11:32.000Z',
#    'page_views': {'page_views_last_week': 74,
#     'page_views_last_month': 458,
#     'page_views_total': 2288,
#     'page_views_last_week_log': 6.22881869049588,
#     'page_views_last_month_log': 8.842350343413809,
#     'page_views_total_log': 11.160501747555687},
#    'columns_name': [],
#    'columns_field_name': [],
#    'columns_datatype': [],
#    'columns_description': [],
#    'columns_format': [],
#    'download_count': 0,
#    'provenance': 'official',
#    'lens_view_type': 'story',
#    'blob_mime_type': None,
#    'hide_from_data_json': False,
#    'publication_date': '2019-08-19T20:08:03.000Z'},
#   'classification': {'categories': [],
#    'tags': [],
#    'domain_tags': [],
#    'domain_metadata': []},
#   'metadata': {'domain': 'sandbox.demo.socrata.com'},
#   'permalink': 'https://sandbox.demo.socrata.com/stories/s/p4nn-nexg',
#   'link': 'https://sandbox.demo.socrata.com/stories/s/p4nn-nexg',
#   'owner': {'id': 'eemb-yw39', 'display_name': 'Sally Socrata'}},
#  {'resource': {'name': "Iowa's Access to Organic Food",
#    'id': 'xaad-83m6',
#    'parent_fxf': ['ai4n-4yn4', 'q6up-dfmm', 'verq-ksee', 'gbq4-g87m'],
#    'description': '',
#    'attribution': None,
#    'attribution_link': None,
#    'contact_email': None,
#    'type': 'story',
#    'updatedAt': '2019-11-01T17:51:38.645Z',
#    'createdAt': '2019-10-29T22:43:16.000Z',
#    'metadata_updated_at': '2019-10-29T22:56:00.000Z',
#    'data_updated_at': '2019-10-29T22:43:16.000Z',
#    'page_views': {'page_views_last_week': 2,
#     'page_views_last_month': 10,
#     'page_views_total': 177,
#     'page_views_last_week_log': 1.5849625007211563,
#     'page_views_last_month_log': 3.4594316186372978,
#     'page_views_total_log': 7.475733430966398},
#    'columns_name': [],
#    'columns_field_name': [],
#    'columns_datatype': [],
#    'columns_description': [],
#    'columns_format': [],
#    'download_count': 0,
#    'provenance': 'official',
#    'lens_view_type': 'story',
#    'blob_mime_type': None,
#    'hide_from_data_json': False,
#    'publication_date': '2019-10-29T22:56:00.000Z'},
#   'classification': {'categories': [],
#    'tags': [],
#    'domain_tags': [],
#    'domain_metadata': []},
#   'metadata': {'domain': 'sandbox.demo.socrata.com'},
#   'permalink': 'https://sandbox.demo.socrata.com/stories/s/xaad-83m6',
#   'link': 'https://sandbox.demo.socrata.com/stories/s/xaad-83m6',
#   'owner': {'id': 'yuhp-vsb6', 'display_name': 'Goeun Park'}},
#  {'resource': {'name': 'Rail-Related Injuries, Illnesses, and Fatalities',
#    'id': 'hjeq-um9p',
#    'parent_fxf': ['vdd7-4iur',
#     'mbnx-3mgj',
#     '9yn7-8kip',
#     'j4pc-xdn9',
#     '9dpf-4pdu'],
#    'description': '',
#    'attribution': None,
#    'attribution_link': None,
#    'contact_email': None,
#    'type': 'story',
#    'updatedAt': '2019-11-11T18:28:03.959Z',
#    'createdAt': '2019-10-29T17:23:01.000Z',
#    'metadata_updated_at': '2019-10-29T17:27:44.000Z',
#    'data_updated_at': '2019-10-29T17:23:01.000Z',
#    'page_views': {'page_views_last_week': 0,
#     'page_views_last_month': 4,
#     'page_views_total': 142,
#     'page_views_last_week_log': 0.0,
#     'page_views_last_month_log': 2.321928094887362,
#     'page_views_total_log': 7.159871336778389},
#    'columns_name': [],
#    'columns_field_name': [],
#    'columns_datatype': [],
#    'columns_description': [],
#    'columns_format': [],
#    'download_count': 0,
#    'provenance': 'official',
#    'lens_view_type': 'story',
#    'blob_mime_type': None,
#    'hide_from_data_json': False,
#    'publication_date': '2019-10-29T17:27:44.000Z'},
#   'classification': {'categories': ['health'],
#    'tags': [],
#    'domain_tags': [],
#    'domain_metadata': []},
#   'metadata': {'domain': 'sandbox.demo.socrata.com'},
#   'permalink': 'https://sandbox.demo.socrata.com/stories/s/hjeq-um9p',
#   'link': 'https://sandbox.demo.socrata.com/stories/s/hjeq-um9p',
#   'owner': {'id': 'rt9e-v5c6', 'display_name': 'Zac Zacal'}},
#  {'resource': {'name': 'Bridges in Seattle: Performance Asset Management',
#    'id': 'r7d6-rebe',
#    'parent_fxf': ['tnpe-34ez',
#     '5azi-mu8b',
#     '3k2v-3fg2',
#     '6vfj-swpb',
#     'vtsy-wnsd',
#     'qgjd-zve3',
#     's74k-9j29'],
#    'description': '',
#    'attribution': None,
#    'attribution_link': None,
#    'contact_email': None,
#    'type': 'story',
#    'updatedAt': '2019-12-19T17:53:55.422Z',
#    'createdAt': '2019-10-29T17:31:03.000Z',
#    'metadata_updated_at': '2019-10-29T17:36:10.000Z',
#    'data_updated_at': '2019-10-29T17:31:03.000Z',
#    'page_views': {'page_views_last_week': 2,
#     'page_views_last_month': 11,
#     'page_views_total': 135,
#     'page_views_last_week_log': 1.5849625007211563,
#     'page_views_last_month_log': 3.5849625007211565,
#     'page_views_total_log': 7.08746284125034},
#    'columns_name': [],
#    'columns_field_name': [],
#    'columns_datatype': [],
#    'columns_description': [],
#    'columns_format': [],
#    'download_count': 0,
#    'provenance': 'official',
#    'lens_view_type': 'story',
#    'blob_mime_type': None,
#    'hide_from_data_json': False,
#    'publication_date': '2019-10-29T17:36:10.000Z'},
#   'classification': {'categories': [],
#    'tags': [],
#    'domain_tags': [],
#    'domain_metadata': []},
#   'metadata': {'domain': 'sandbox.demo.socrata.com'},
#   'permalink': 'https://sandbox.demo.socrata.com/stories/s/r7d6-rebe',
#   'link': 'https://sandbox.demo.socrata.com/stories/s/r7d6-rebe',
#   'owner': {'id': '3fca-ur3r', 'display_name': 'Mathias Burton'}},
#  {'resource': {'name': 'Create and Manage Your Socrata Dataset',
#    'id': 'qpqr-2drg',
#    'parent_fxf': None,
#    'description': 'Learn the data publishing workflow from end-to-end for your Socrata site. Create drafts, publish datasets, edit and update data, and manage the use of your dataset. \n\nAfter this course you will be able to:\n\n• Prepare a dataset for uploading\n• Create a draft dataset\n• Perform basic transformation and validation of your data with the Socrata manual import experience\n• Publish data\n• Edit and update your dataset\n• Manage and use your newly published dataset',
#    'attribution': None,
#    'attribution_link': None,
#    'contact_email': None,
#    'type': 'story',
#    'updatedAt': '2019-11-01T15:20:25.131Z',
#    'createdAt': '2019-08-22T15:45:32.000Z',
#    'metadata_updated_at': '2019-10-30T21:43:09.000Z',
#    'data_updated_at': '2019-08-22T15:45:32.000Z',
#    'page_views': {'page_views_last_week': 8,
#     'page_views_last_month': 33,
#     'page_views_total': 128,
#     'page_views_last_week_log': 3.1699250014423126,
#     'page_views_last_month_log': 5.08746284125034,
#     'page_views_total_log': 7.011227255423254},
#    'columns_name': [],
#    'columns_field_name': [],
#    'columns_datatype': [],
#    'columns_description': [],
#    'columns_format': [],
#    'download_count': 0,
#    'provenance': 'official',
#    'lens_view_type': 'story',
#    'blob_mime_type': None,
#    'hide_from_data_json': False,
#    'publication_date': '2019-08-22T15:46:17.000Z'},
#   'classification': {'categories': ['infrastructure'],
#    'tags': [],
#    'domain_tags': [],
#    'domain_metadata': []},
#   'metadata': {'domain': 'sandbox.demo.socrata.com'},
#   'permalink': 'https://sandbox.demo.socrata.com/stories/s/qpqr-2drg',
#   'link': 'https://sandbox.demo.socrata.com/stories/s/qpqr-2drg',
#   'owner': {'id': 'eemb-yw39', 'display_name': 'Sally Socrata'}},
#  {'resource': {'name': 'Map Your Data on Socrata',
#    'id': 'y4m4-7v7z',
#    'parent_fxf': None,
#    'description': '',
#    'attribution': None,
#    'attribution_link': None,
#    'contact_email': None,
#    'type': 'story',
#    'updatedAt': '2019-11-01T15:22:45.124Z',
#    'createdAt': '2019-08-22T15:47:54.000Z',
#    'metadata_updated_at': '2019-08-22T15:48:12.000Z',
#    'data_updated_at': '2019-08-22T15:47:54.000Z',
#    'page_views': {'page_views_last_week': 16,
#     'page_views_last_month': 28,
#     'page_views_total': 96,
#     'page_views_last_week_log': 4.08746284125034,
#     'page_views_last_month_log': 4.857980995127573,
#     'page_views_total_log': 6.599912842187128},
#    'columns_name': [],
#    'columns_field_name': [],
#    'columns_datatype': [],
#    'columns_description': [],
#    'columns_format': [],
#    'download_count': 0,
#    'provenance': 'official',
#    'lens_view_type': 'story',
#    'blob_mime_type': None,
#    'hide_from_data_json': False,
#    'publication_date': '2019-08-22T15:48:12.000Z'},
#   'classification': {'categories': [],
#    'tags': [],
#    'domain_tags': [],
#    'domain_metadata': []},
#   'metadata': {'domain': 'sandbox.demo.socrata.com'},
#   'permalink': 'https://sandbox.demo.socrata.com/stories/s/y4m4-7v7z',
#   'link': 'https://sandbox.demo.socrata.com/stories/s/y4m4-7v7z',
#   'owner': {'id': 'eemb-yw39', 'display_name': 'Sally Socrata'}},
#  {'resource': {'name': 'Explore Data with Charts on Socrata',
#    'id': 'kkej-575h',
#    'parent_fxf': None,
#    'description': 'Use data to answer questions. To do that, you will create a:\n• Scatterplot to understand the value of visualizations.\n• 100% stacked bar chart to analyze qualitative data.\n• Pie chart to compare categories in data.\n• Timeline chart/combo chart to see trends over time.',
#    'attribution': None,
#    'attribution_link': None,
#    'contact_email': None,
#    'type': 'story',
#    'updatedAt': '2019-10-31T14:54:14.947Z',
#    'createdAt': '2019-08-22T15:47:00.000Z',
#    'metadata_updated_at': '2019-10-30T23:12:33.000Z',
#    'data_updated_at': '2019-08-22T15:47:00.000Z',
#    'page_views': {'page_views_last_week': 5,
#     'page_views_last_month': 21,
#     'page_views_total': 83,
#     'page_views_last_week_log': 2.584962500721156,
#     'page_views_last_month_log': 4.459431618637297,
#     'page_views_total_log': 6.39231742277876},
#    'columns_name': [],
#    'columns_field_name': [],
#    'columns_datatype': [],
#    'columns_description': [],
#    'columns_format': [],
#    'download_count': 0,
#    'provenance': 'official',
#    'lens_view_type': 'story',
#    'blob_mime_type': None,
#    'hide_from_data_json': False,
#    'publication_date': '2019-08-22T15:47:28.000Z'},
#   'classification': {'categories': [],
#    'tags': [],
#    'domain_tags': [],
#    'domain_metadata': []},
#   'metadata': {'domain': 'sandbox.demo.socrata.com'},
#   'permalink': 'https://sandbox.demo.socrata.com/stories/s/kkej-575h',
#   'link': 'https://sandbox.demo.socrata.com/stories/s/kkej-575h',
#   'owner': {'id': 'eemb-yw39', 'display_name': 'Sally Socrata'}},
#  {'resource': {'name': 'Get In Touch',
#    'id': 'v75x-kiaj',
#    'parent_fxf': None,
#    'description': 'Fill out this form to contact a Tyler Technologies representative about Socrata.',
#    'attribution': None,
#    'attribution_link': None,
#    'contact_email': '',
#    'type': 'story',
#    'updatedAt': '2019-11-01T15:44:30.978Z',
#    'createdAt': '2019-10-08T15:10:42.000Z',
#    'metadata_updated_at': '2019-10-29T21:30:24.000Z',
#    'data_updated_at': '2019-10-08T15:10:42.000Z',
#    'page_views': {'page_views_last_week': 1,
#     'page_views_last_month': 5,
#     'page_views_total': 67,
#     'page_views_last_week_log': 1.0,
#     'page_views_last_month_log': 2.584962500721156,
#     'page_views_total_log': 6.08746284125034},
#    'columns_name': [],
#    'columns_field_name': [],
#    'columns_datatype': [],
#    'columns_description': [],
#    'columns_format': [],
#    'download_count': 0,
#    'provenance': 'official',
#    'lens_view_type': 'story',
#    'blob_mime_type': None,
#    'hide_from_data_json': False,
#    'publication_date': '2019-10-08T15:13:40.000Z'},
#   'classification': {'categories': [],
#    'tags': [],
#    'domain_tags': [],
#    'domain_metadata': []},
#   'metadata': {'domain': 'sandbox.demo.socrata.com'},
#   'permalink': 'https://sandbox.demo.socrata.com/stories/s/v75x-kiaj',
#   'link': 'https://sandbox.demo.socrata.com/stories/s/v75x-kiaj',
#   'owner': {'id': 'eemb-yw39', 'display_name': 'Sally Socrata'}},
#  {'resource': {'name': 'Finding Services in San Bernardino for Women, Youth, and Families',
#    'id': '2ui8-95ps',
#    'parent_fxf': ['5xq8-q6sd'],
#    'description': 'This is a map of public reentry resources for women, youth, and families. \nZoom in to find resources near you.\nHover over the points for descriptions of those services and contact information.\nHover over the bus lines to see which routes go to those resources.',
#    'attribution': None,
#    'attribution_link': None,
#    'contact_email': None,
#    'type': 'story',
#    'updatedAt': '2019-10-30T22:43:46.539Z',
#    'createdAt': '2019-10-30T22:39:58.000Z',
#    'metadata_updated_at': '2019-10-30T22:43:46.000Z',
#    'data_updated_at': '2019-10-30T22:39:58.000Z',
#    'page_views': {'page_views_last_week': 1,
#     'page_views_last_month': 10,
#     'page_views_total': 55,
#     'page_views_last_week_log': 1.0,
#     'page_views_last_month_log': 3.4594316186372978,
#     'page_views_total_log': 5.807354922057605},
#    'columns_name': [],
#    'columns_field_name': [],
#    'columns_datatype': [],
#    'columns_description': [],
#    'columns_format': [],
#    'download_count': 0,
#    'provenance': 'official',
#    'lens_view_type': 'story',
#    'blob_mime_type': None,
#    'hide_from_data_json': False,
#    'publication_date': '2019-10-30T22:43:46.000Z'},
#   'classification': {'categories': ['public safety', 'transportation'],
#    'tags': [],
#    'domain_tags': [],
#    'domain_metadata': []},
#   'metadata': {'domain': 'sandbox.demo.socrata.com'},
#   'permalink': 'https://sandbox.demo.socrata.com/stories/s/2ui8-95ps',
#   'link': 'https://sandbox.demo.socrata.com/stories/s/2ui8-95ps',
#   'owner': {'id': 'eemb-yw39', 'display_name': 'Sally Socrata'}},
#  {'resource': {'name': 'Tell a Story with Socrata Perspectives',
#    'id': 'h6ub-a6cz',
#    'parent_fxf': None,
#    'description': '',
#    'attribution': None,
#    'attribution_link': None,
#    'contact_email': None,
#    'type': 'story',
#    'updatedAt': '2019-11-01T15:48:30.047Z',
#    'createdAt': '2019-08-22T15:48:32.000Z',
#    'metadata_updated_at': '2019-08-22T15:48:46.000Z',
#    'data_updated_at': '2019-08-22T15:48:32.000Z',
#    'page_views': {'page_views_last_week': 2,
#     'page_views_last_month': 8,
#     'page_views_total': 47,
#     'page_views_last_week_log': 1.5849625007211563,
#     'page_views_last_month_log': 3.1699250014423126,
#     'page_views_total_log': 5.584962500721157},
#    'columns_name': [],
#    'columns_field_name': [],
#    'columns_datatype': [],
#    'columns_description': [],
#    'columns_format': [],
#    'download_count': 0,
#    'provenance': 'official',
#    'lens_view_type': 'story',
#    'blob_mime_type': None,
#    'hide_from_data_json': False,
#    'publication_date': '2019-08-22T15:48:46.000Z'},
#   'classification': {'categories': [],
#    'tags': [],
#    'domain_tags': [],
#    'domain_metadata': []},
#   'metadata': {'domain': 'sandbox.demo.socrata.com'},
#   'permalink': 'https://sandbox.demo.socrata.com/stories/s/h6ub-a6cz',
#   'link': 'https://sandbox.demo.socrata.com/stories/s/h6ub-a6cz',
#   'owner': {'id': 'eemb-yw39', 'display_name': 'Sally Socrata'}},
#  {'resource': {'name': 'Deputy-Involved Shootings in LA County',
#    'id': 'g9r9-scqj',
#    'parent_fxf': ['756t-kjca',
#     '83f5-pzqj',
#     'h2vw-w6k9',
#     '38z4-riib',
#     'rq74-2sre',
#     'cvxv-qebb',
#     '7thv-kvrq',
#     '7rye-5azg',
#     'fees-mg4g'],
#    'description': '',
#    'attribution': None,
#    'attribution_link': None,
#    'contact_email': None,
#    'type': 'story',
#    'updatedAt': '2019-10-29T21:04:05.723Z',
#    'createdAt': '2019-10-29T18:36:17.000Z',
#    'metadata_updated_at': '2019-10-29T19:11:39.000Z',
#    'data_updated_at': '2019-10-29T18:36:17.000Z',
#    'page_views': {'page_views_last_week': 0,
#     'page_views_last_month': 0,
#     'page_views_total': 35,
#     'page_views_last_week_log': 0.0,
#     'page_views_last_month_log': 0.0,
#     'page_views_total_log': 5.169925001442312},
#    'columns_name': [],
#    'columns_field_name': [],
#    'columns_datatype': [],
#    'columns_description': [],
#    'columns_format': [],
#    'download_count': 0,
#    'provenance': 'official',
#    'lens_view_type': 'story',
#    'blob_mime_type': None,
#    'hide_from_data_json': False,
#    'publication_date': '2019-10-29T19:11:39.000Z'},
#   'classification': {'categories': [],
#    'tags': [],
#    'domain_tags': [],
#    'domain_metadata': []},
#   'metadata': {'domain': 'sandbox.demo.socrata.com'},
#   'permalink': 'https://sandbox.demo.socrata.com/stories/s/g9r9-scqj',
#   'link': 'https://sandbox.demo.socrata.com/stories/s/g9r9-scqj',
#   'owner': {'id': 'eemb-yw39', 'display_name': 'Sally Socrata'}},
#  {'resource': {'name': 'Rail-Related Injuries, Illnesses, and Fatalities',
#    'id': 'aig8-7vak',
#    'parent_fxf': None,
#    'description': 'A list of rail related casualties reported via F 6180.55A\nTaken from\nhttps://data.transportation.gov/Railroads/Rail-related-Injuries-Illnesses-Fatalities/6cse-juc3',
#    'attribution': None,
#    'attribution_link': None,
#    'contact_email': None,
#    'type': 'dataset',
#    'updatedAt': '2019-10-30T23:10:31.000Z',
#    'createdAt': '2019-10-28T22:27:37.000Z',
#    'metadata_updated_at': '2019-10-30T23:10:31.000Z',
#    'data_updated_at': '2019-10-29T16:00:01.000Z',
#    'page_views': {'page_views_last_week': 0,
#     'page_views_last_month': 0,
#     'page_views_total': 30,
#     'page_views_last_week_log': 0.0,
#     'page_views_last_month_log': 0.0,
#     'page_views_total_log': 4.954196310386876},
#    'columns_name': ['Latitude',
#     'id',
#     'Display Time',
#     'LocationC',
#     'LocationB',
#     'Injury',
#     'Display Date',
#     'Job',
#     'Days Absent',
#     'Reporting Railroad',
#     'Reporting Railroad Code',
#     'State Name',
#     'Physical Act',
#     'Days Rest',
#     'Fiscal Year',
#     'Drug Test',
#     'County',
#     'Age',
#     'Non-Suicide Injury',
#     'Reportable Train Accident',
#     'Type of Person',
#     'Alcohol Test',
#     'Calendar Year',
#     'Longitude',
#     'Occupational Illness',
#     'LocationA',
#     'Non-Suicide Fatality',
#     'GeoLocation',
#     'Grade Crossing Collision'],
#    'columns_field_name': ['latitude',
#     'id',
#     'display_time',
#     'locationc',
#     'locationb',
#     'injury',
#     'display_date',
#     'job',
#     'days_absent',
#     'reporting_railroad',
#     'reporting_railroad_code',
#     'state_name',
#     'physical_act',
#     'days_rest',
#     'fiscal_year',
#     'drug_test',
#     'county',
#     'age',
#     'non_suicide_injury',
#     'reportable_train_accident',
#     'type_of_person',
#     'alcohol_test',
#     'calendar_year',
#     'longitude',
#     'occupational_illness',
#     'locationa',
#     'non_suicide_fatality',
#     'geolocation',
#     'grade_crossing_collision'],
#    'columns_datatype': ['Number',
#     'Number',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Calendar date',
#     'Text',
#     'Number',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Number',
#     'Text',
#     'Number',
#     'Text',
#     'Number',
#     'Number',
#     'Checkbox',
#     'Text',
#     'Number',
#     'Text',
#     'Number',
#     'Number',
#     'Text',
#     'Number',
#     'Point',
#     'Checkbox'],
#    'columns_description': ['',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     ''],
#    'columns_format': [{},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {}],
#    'download_count': None,
#    'provenance': 'official',
#    'lens_view_type': 'tabular',
#    'blob_mime_type': None,
#    'hide_from_data_json': False,
#    'publication_date': '2019-10-29T16:00:01.000Z'},
#   'classification': {'categories': ['health', 'environment'],
#    'tags': [],
#    'domain_tags': ['safety', 'train', 'rail'],
#    'domain_metadata': []},
#   'metadata': {'domain': 'sandbox.demo.socrata.com'},
#   'permalink': 'https://sandbox.demo.socrata.com/d/aig8-7vak',
#   'link': 'https://sandbox.demo.socrata.com/dataset/Rail-Related-Injuries-Illnesses-and-Fatalities/aig8-7vak',
#   'owner': {'id': 'rt9e-v5c6', 'display_name': 'Zac Zacal'}},
#  {'resource': {'name': 'LA County Boundary',
#    'id': 'nsjr-ns6y',
#    'parent_fxf': None,
#    'description': 'Boundary of L.A. County including Catalina & San Clemente islands.',
#    'attribution': 'LA County',
#    'attribution_link': 'https://egis3.lacounty.gov/dataportal/drp_county_boundary/',
#    'contact_email': None,
#    'type': 'dataset',
#    'updatedAt': '2019-10-29T15:04:13.000Z',
#    'createdAt': '2019-10-29T15:02:33.000Z',
#    'metadata_updated_at': '2019-10-29T15:04:13.000Z',
#    'data_updated_at': '2019-10-29T15:04:12.000Z',
#    'page_views': {'page_views_last_week': 0,
#     'page_views_last_month': 0,
#     'page_views_total': 23,
#     'page_views_last_week_log': 0.0,
#     'page_views_last_month_log': 0.0,
#     'page_views_total_log': 4.584962500721157},
#    'columns_name': ['Shape_len', 'LINE_TYPE', 'the_geom'],
#    'columns_field_name': ['shape_len', 'line_type', 'the_geom'],
#    'columns_datatype': ['Number', 'Text', 'MultiLine'],
#    'columns_description': ['', '', ''],
#    'columns_format': [{}, {}, {}],
#    'download_count': 0,
#    'provenance': 'official',
#    'lens_view_type': 'tabular',
#    'blob_mime_type': None,
#    'hide_from_data_json': False,
#    'publication_date': '2019-10-29T15:04:13.000Z'},
#   'classification': {'categories': [],
#    'tags': [],
#    'domain_tags': ['county', 'boundary', 'shapefile', 'map'],
#    'domain_metadata': []},
#   'metadata': {'domain': 'sandbox.demo.socrata.com'},
#   'permalink': 'https://sandbox.demo.socrata.com/d/nsjr-ns6y',
#   'link': 'https://sandbox.demo.socrata.com/dataset/LA-County-Boundary/nsjr-ns6y',
#   'owner': {'id': 'eemb-yw39', 'display_name': 'Sally Socrata'}},
#  {'resource': {'name': 'Ped Bridges by Council District',
#    'id': 'qgjd-zve3',
#    'parent_fxf': ['2dep-cf6s'],
#    'description': '',
#    'attribution': None,
#    'attribution_link': None,
#    'contact_email': None,
#    'type': 'chart',
#    'updatedAt': '2019-12-20T18:53:19.000Z',
#    'createdAt': '2019-10-29T18:25:58.000Z',
#    'metadata_updated_at': '2019-12-20T18:53:19.000Z',
#    'data_updated_at': '2019-12-19T15:19:36.000Z',
#    'page_views': {'page_views_last_week': 0,
#     'page_views_last_month': 0,
#     'page_views_total': 21,
#     'page_views_last_week_log': 0.0,
#     'page_views_last_month_log': 0.0,
#     'page_views_total_log': 4.459431618637297},
#    'columns_name': [],
#    'columns_field_name': [],
#    'columns_datatype': [],
#    'columns_description': [],
#    'columns_format': [],
#    'download_count': 0,
#    'provenance': 'official',
#    'lens_view_type': 'tabular',
#    'blob_mime_type': None,
#    'hide_from_data_json': False,
#    'publication_date': '2019-12-20T18:53:19.000Z'},
#   'classification': {'categories': [],
#    'tags': [],
#    'domain_tags': [],
#    'domain_metadata': []},
#   'metadata': {'domain': 'sandbox.demo.socrata.com'},
#   'permalink': 'https://sandbox.demo.socrata.com/d/qgjd-zve3',
#   'link': 'https://sandbox.demo.socrata.com/dataset/Ped-Bridges-by-Council-District/qgjd-zve3',
#   'owner': {'id': '3fca-ur3r', 'display_name': 'Mathias Burton'}},
#  {'resource': {'name': 'LA County Shootings Incidents 2010-2019',
#    'id': 'uiad-qc6z',
#    'parent_fxf': None,
#    'description': 'Shooting incidents in LA county 2010-2019',
#    'attribution': 'LA County',
#    'attribution_link': 'https://data.lacounty.gov/Criminal/All-Shootings-Incident-Summary-Count-2010-to-Prese/t5tx-83xe',
#    'contact_email': None,
#    'type': 'dataset',
#    'updatedAt': '2019-10-29T16:57:22.000Z',
#    'createdAt': '2019-10-28T21:08:47.000Z',
#    'metadata_updated_at': '2019-10-29T16:57:22.000Z',
#    'data_updated_at': '2019-10-29T15:10:01.000Z',
#    'page_views': {'page_views_last_week': 0,
#     'page_views_last_month': 0,
#     'page_views_total': 18,
#     'page_views_last_week_log': 0.0,
#     'page_views_last_month_log': 0.0,
#     'page_views_total_log': 4.247927513443585},
#    'columns_name': ['Location',
#     'HANDLING UNIT NAME',
#     'HANDLING UNIT ID',
#     'ADDRESS',
#     'ZIP',
#     'CITY',
#     'INCIDENT YEAR',
#     'INCIDENT DATE',
#     'INCIDENT NUMBER',
#     'HIT SHOOTING',
#     'WARNING SHOT',
#     'OTHER SHOOTING',
#     'REPORTING DISTRICT',
#     'UNINTENTIONAL DISCHARGE',
#     'ANIMAL SHOOTING',
#     'NON HIT SHOOTING',
#     'STATE',
#     'SHOOTING TYPE',
#     'LA County Census Tracts'],
#    'columns_field_name': ['lat_long',
#     'handling_unit_name',
#     'handling_unit_id',
#     'address',
#     'zip',
#     'city',
#     'incident_year',
#     'incident_date',
#     'incident_number',
#     'hit_shooting',
#     'warning_shot',
#     'other_shooting',
#     'reporting_district',
#     'unintentional_discharge',
#     'animal_shooting',
#     'non_hit_shooting',
#     'state',
#     'shooting_type',
#     ':@computed_region_d5up_3ngn'],
#    'columns_datatype': ['Point',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Calendar date',
#     'Text',
#     'Number',
#     'Number',
#     'Number',
#     'Text',
#     'Number',
#     'Number',
#     'Number',
#     'Text',
#     'Text',
#     'Number'],
#    'columns_description': ['',
#     "Sheriff's patrol station or bureau ID handling the incident.",
#     "Sheriff's patrol station or bureau ID handling the incident.",
#     '',
#     '',
#     'City where shooting incident occurred. ',
#     'Year the shooting incident occurred.',
#     'Date and time the shooting incident occurred.',
#     'System-assigned reference number',
#     'Hit shooting incident count',
#     'Waning shot incident count',
#     'Other shooting incident count',
#     'Identifies geographical areas within a patrol station.',
#     'Unintentional discharge incident count',
#     'Animal shooting incident count',
#     'Non-Hit shooting incident count',
#     '',
#     'Hit Shooting, Non-Hit Shooting, Animal Shooting, Other Shooting, Unintentional Discharge, Warning Shot',
#     ''],
#    'columns_format': [{},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {}],
#    'download_count': None,
#    'provenance': 'official',
#    'lens_view_type': 'tabular',
#    'blob_mime_type': None,
#    'hide_from_data_json': False,
#    'publication_date': '2019-10-29T16:57:22.000Z'},
#   'classification': {'categories': ['public safety',
#     'environment',
#     'social services'],
#    'tags': [],
#    'domain_category': 'Public Safety',
#    'domain_tags': ['violence',
#     'violent crime',
#     'shooting',
#     'deputy',
#     'sheriff',
#     'crime',
#     'shootings'],
#    'domain_metadata': []},
#   'metadata': {'domain': 'sandbox.demo.socrata.com'},
#   'permalink': 'https://sandbox.demo.socrata.com/d/uiad-qc6z',
#   'link': 'https://sandbox.demo.socrata.com/Public-Safety/LA-County-Shootings-Incidents-2010-2019/uiad-qc6z',
#   'owner': {'id': 'eemb-yw39', 'display_name': 'Sally Socrata'}},
#  {'resource': {'name': 'Bridge Asset Assessments',
#    'id': '2dep-cf6s',
#    'parent_fxf': None,
#    'description': '',
#    'attribution': None,
#    'attribution_link': None,
#    'contact_email': None,
#    'type': 'dataset',
#    'updatedAt': '2019-12-19T15:19:36.000Z',
#    'createdAt': '2019-10-29T17:18:41.000Z',
#    'metadata_updated_at': '2019-12-19T15:19:34.000Z',
#    'data_updated_at': '2019-12-19T15:19:36.000Z',
#    'page_views': {'page_views_last_week': 0,
#     'page_views_last_month': 0,
#     'page_views_total': 17,
#     'page_views_last_week_log': 0.0,
#     'page_views_last_month_log': 0.0,
#     'page_views_total_log': 4.169925001442312},
#    'columns_name': ['Bridge Type',
#     'Date Built',
#     '2017 SR for Peds',
#     '2016 SR Reported',
#     'Moveable/RR',
#     '2016 SR for Peds',
#     '2015 NBI SR',
#     '2016 SR',
#     'Council District',
#     'SR',
#     'Replacement Value00',
#     'SD or FO',
#     '2014 reort SR',
#     'NBI SR',
#     'Deck Area',
#     'Year Built',
#     'bridge_no',
#     'Replacement Value',
#     'Area',
#     'Width',
#     'Age',
#     'X',
#     'SR for reporting',
#     'T',
#     'Cond Rating',
#     'BRGUNITID',
#     '2017 SR',
#     'W',
#     'Length',
#     'Whole Bridge Count',
#     'Count',
#     'SR for Peds',
#     'bridge_name',
#     'the_geom',
#     'Date',
#     'Year',
#     'Ped?',
#     'MOVABLE?',
#     'Posted?',
#     'Age Range',
#     'Design Life'],
#    'columns_field_name': ['bridge_type',
#     'date_built',
#     '_2017_sr_for_peds',
#     '_2016_sr_reported',
#     'moveable_rr',
#     '_2016_sr_for_peds',
#     '_2015_nbi_sr',
#     '_2016_sr',
#     'council_district',
#     'sr',
#     'replacement_value00',
#     'sd_or_fo',
#     '_2014_reort_sr',
#     'nbi_sr',
#     'deck_area',
#     'year_built',
#     'bridge_no',
#     'replacement_value',
#     'area',
#     'width',
#     'age',
#     'x',
#     'sr_for_reporting',
#     't',
#     'cond_rating',
#     'brgunitid',
#     '_2017_sr',
#     'w',
#     'length',
#     'whole_bridge_count',
#     'count',
#     'sr_for_peds',
#     'bridge_name',
#     'the_geom',
#     'date',
#     'year',
#     'ped',
#     'movable',
#     'posted',
#     'age_range',
#     'design_life'],
#    'columns_datatype': ['Text',
#     'Calendar date',
#     'Number',
#     'Number',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Number',
#     'Number',
#     'Text',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Text',
#     'Number',
#     'Text',
#     'Text',
#     'Text',
#     'Number',
#     'Text',
#     'Number',
#     'Text',
#     'Number',
#     'Text',
#     'Text',
#     'MultiLine',
#     'Calendar date',
#     'Number',
#     'Checkbox',
#     'Text',
#     'Text',
#     'Text',
#     'Text'],
#    'columns_description': ['',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     ''],
#    'columns_format': [{},
#     {'view': 'date_y'},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {'noCommas': 'true'},
#     {},
#     {'precisionStyle': 'currency'},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {'view': 'date_y'},
#     {'noCommas': 'true'},
#     {},
#     {},
#     {},
#     {},
#     {}],
#    'download_count': 0,
#    'provenance': 'official',
#    'lens_view_type': 'tabular',
#    'blob_mime_type': None,
#    'hide_from_data_json': False,
#    'publication_date': '2019-10-29T17:20:16.000Z'},
#   'classification': {'categories': [],
#    'tags': [],
#    'domain_tags': [],
#    'domain_metadata': []},
#   'metadata': {'domain': 'sandbox.demo.socrata.com'},
#   'permalink': 'https://sandbox.demo.socrata.com/d/2dep-cf6s',
#   'link': 'https://sandbox.demo.socrata.com/dataset/Bridge-Asset-Assessments/2dep-cf6s',
#   'owner': {'id': '3fca-ur3r', 'display_name': 'Mathias Burton'}},
#  {'resource': {'name': 'Deputy Details for Hit and Non-hit shooting 2010-2019',
#    'id': 'qbzc-tyub',
#    'parent_fxf': None,
#    'description': 'Information about the deputies involved in shootings',
#    'attribution': 'LA County',
#    'attribution_link': 'https://data.lacounty.gov/Criminal/Deputy-Details-Hit-Shooting-Incidents-and-Non-Hit-/7jc3-gsk7',
#    'contact_email': None,
#    'type': 'dataset',
#    'updatedAt': '2019-10-29T18:02:23.000Z',
#    'createdAt': '2019-10-29T14:44:15.000Z',
#    'metadata_updated_at': '2019-10-29T18:02:21.000Z',
#    'data_updated_at': '2019-10-29T18:02:23.000Z',
#    'page_views': {'page_views_last_week': 0,
#     'page_views_last_month': 0,
#     'page_views_total': 14,
#     'page_views_last_week_log': 0.0,
#     'page_views_last_month_log': 0.0,
#     'page_views_total_log': 3.9068905956085187},
#    'columns_name': ['WEAPON INVOLVED CATEGORY DESC',
#     'DEPUTY ASSIGNED UNIT NAME',
#     'LOCATION',
#     'ADDRESS',
#     'INCIDENT DATE',
#     'INCIDENT NUMBER',
#     'ZIP',
#     'TRAINING',
#     '# OF PERSONS',
#     'INVOLVED IN PREVIOUS SHOOTINGS',
#     'DECEASED',
#     'STATE',
#     'PERSON RACE',
#     '# OF PREVIOUS SHOOTINGS',
#     'YEARS OF SERVICE',
#     'DISTRICT ATTORNEY ACTION',
#     'DEPUTY GENDER',
#     'WEAPON INVOLVED CATEGORY',
#     'DEPUTY ASSIGNED UNIT',
#     'DEPUTY AGE',
#     'DEPUTY RACE',
#     'REPORTING DISTRICT',
#     'CITY',
#     'INCIDENT TYPE',
#     'WOUNDED'],
#    'columns_field_name': ['weapon_involved_category_1',
#     'deputy_assigned_unit_name',
#     'location',
#     'address',
#     'incident_date',
#     'incident_number',
#     'zip',
#     'training',
#     'number_persons',
#     'involved_in_previous_shootings',
#     'deceased',
#     'state',
#     'person_race',
#     'number_previous_shootings',
#     'years_of_service',
#     'district_attorney_action',
#     'deputy_gender',
#     'weapon_involved_category',
#     'deputy_assigned_unit',
#     'deputy_age',
#     'deputy_race',
#     'reporting_district',
#     'city',
#     'incident_type',
#     'wounded'],
#    'columns_datatype': ['Text',
#     'Text',
#     'Point',
#     'Text',
#     'Calendar date',
#     'Text',
#     'Text',
#     'Checkbox',
#     'Number',
#     'Checkbox',
#     'Checkbox',
#     'Text',
#     'Text',
#     'Number',
#     'Number',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Number',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Checkbox'],
#    'columns_description': ['',
#     '',
#     '',
#     '',
#     'Date and time the shooting incident occurred.',
#     'System assigned reference number',
#     '',
#     'Training (Y) means that training was recommended for the deputies after a review of the shooting was completed. Training (N) means the training was not recommended.',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     'Identifies geographical areas within a patrol station.',
#     'City of shooting incident.',
#     'Hit Shooting, Non-Hit Shooting, Warning Shot, Animal Shooting, Unintentional Discharge',
#     ''],
#    'columns_format': [{},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {}],
#    'download_count': None,
#    'provenance': 'official',
#    'lens_view_type': 'tabular',
#    'blob_mime_type': None,
#    'hide_from_data_json': False,
#    'publication_date': '2019-10-29T14:51:59.000Z'},
#   'classification': {'categories': ['environment',
#     'public safety',
#     'social services'],
#    'tags': [],
#    'domain_category': 'Public Safety',
#    'domain_tags': ['violence',
#     'violent crime',
#     'sheriff',
#     'shooting',
#     'shootings',
#     'deputy'],
#    'domain_metadata': []},
#   'metadata': {'domain': 'sandbox.demo.socrata.com'},
#   'permalink': 'https://sandbox.demo.socrata.com/d/qbzc-tyub',
#   'link': 'https://sandbox.demo.socrata.com/Public-Safety/Deputy-Details-for-Hit-and-Non-hit-shooting-2010-2/qbzc-tyub',
#   'owner': {'id': 'eemb-yw39', 'display_name': 'Sally Socrata'}},
#  {'resource': {'name': 'Shootings in LA County Over Time',
#    'id': 'yk26-zgy4',
#    'parent_fxf': ['uiad-qc6z'],
#    'description': 'Shooting incidents in LA county 2010-2019',
#    'attribution': 'LA County',
#    'attribution_link': 'https://data.lacounty.gov/Criminal/All-Shootings-Incident-Summary-Count-2010-to-Prese/t5tx-83xe',
#    'contact_email': None,
#    'type': 'chart',
#    'updatedAt': '2019-10-29T17:18:36.000Z',
#    'createdAt': '2019-10-29T17:18:07.000Z',
#    'metadata_updated_at': '2019-10-29T17:18:36.000Z',
#    'data_updated_at': '2019-10-29T15:10:01.000Z',
#    'page_views': {'page_views_last_week': 0,
#     'page_views_last_month': 0,
#     'page_views_total': 12,
#     'page_views_last_week_log': 0.0,
#     'page_views_last_month_log': 0.0,
#     'page_views_total_log': 3.700439718141092},
#    'columns_name': [],
#    'columns_field_name': [],
#    'columns_datatype': [],
#    'columns_description': [],
#    'columns_format': [],
#    'download_count': 0,
#    'provenance': 'official',
#    'lens_view_type': 'tabular',
#    'blob_mime_type': None,
#    'hide_from_data_json': False,
#    'publication_date': '2019-10-29T17:18:36.000Z'},
#   'classification': {'categories': [],
#    'tags': [],
#    'domain_category': 'Public Safety',
#    'domain_tags': [],
#    'domain_metadata': []},
#   'metadata': {'domain': 'sandbox.demo.socrata.com'},
#   'permalink': 'https://sandbox.demo.socrata.com/d/yk26-zgy4',
#   'link': 'https://sandbox.demo.socrata.com/Public-Safety/Shootings-in-LA-County-Over-Time/yk26-zgy4',
#   'owner': {'id': 'eemb-yw39', 'display_name': 'Sally Socrata'}},
#  {'resource': {'name': 'Asset Value and Sufficiency',
#    'id': '3k2v-3fg2',
#    'parent_fxf': ['2dep-cf6s'],
#    'description': '',
#    'attribution': None,
#    'attribution_link': None,
#    'contact_email': None,
#    'type': 'chart',
#    'updatedAt': '2019-12-19T15:19:36.000Z',
#    'createdAt': '2019-10-29T17:24:24.000Z',
#    'metadata_updated_at': '2019-12-19T15:08:49.000Z',
#    'data_updated_at': '2019-12-19T15:19:36.000Z',
#    'page_views': {'page_views_last_week': 0,
#     'page_views_last_month': 0,
#     'page_views_total': 9,
#     'page_views_last_week_log': 0.0,
#     'page_views_last_month_log': 0.0,
#     'page_views_total_log': 3.3219280948873626},
#    'columns_name': [],
#    'columns_field_name': [],
#    'columns_datatype': [],
#    'columns_description': [],
#    'columns_format': [],
#    'download_count': 0,
#    'provenance': 'official',
#    'lens_view_type': 'tabular',
#    'blob_mime_type': None,
#    'hide_from_data_json': False,
#    'publication_date': '2019-12-19T15:08:49.000Z'},
#   'classification': {'categories': [],
#    'tags': [],
#    'domain_tags': [],
#    'domain_metadata': []},
#   'metadata': {'domain': 'sandbox.demo.socrata.com'},
#   'permalink': 'https://sandbox.demo.socrata.com/d/3k2v-3fg2',
#   'link': 'https://sandbox.demo.socrata.com/dataset/Asset-Value-and-Sufficiency/3k2v-3fg2',
#   'owner': {'id': '3fca-ur3r', 'display_name': 'Mathias Burton'}},
#  {'resource': {'name': 'Iowa Total Poverty Rate and Children Living Under Poverty',
#    'id': 'ai4n-4yn4',
#    'parent_fxf': ['y5nh-twdu'],
#    'description': "The U.S. Census Bureau's Small Area Income and Poverty Estimates (SAIPE) program provides annual estimates of income and poverty statistics for all school districts, counties, and states. The main objective of this program is to provide estimates of income and poverty for the administration of federal programs and the allocation of federal funds to local jurisdictions. In addition to these federal programs, state and local programs use the income and poverty estimates for distributing funds and managing programs.\n\nThe SAIPE program produces the following county and state estimates:\n\n- total number of people in poverty\n- number of children under age 5 in poverty (for states only)\n- number of related children ages 5 to 17 in families in poverty\n- number of children under age 18 in poverty\n- median household income",
#    'attribution': 'Census Bureau',
#    'attribution_link': 'https://www.census.gov/programs-surveys/saipe.html',
#    'contact_email': None,
#    'type': 'chart',
#    'updatedAt': '2019-10-29T22:41:04.000Z',
#    'createdAt': '2019-10-29T22:40:42.000Z',
#    'metadata_updated_at': '2019-10-29T22:41:04.000Z',
#    'data_updated_at': '2019-10-29T22:20:47.000Z',
#    'page_views': {'page_views_last_week': 0,
#     'page_views_last_month': 0,
#     'page_views_total': 8,
#     'page_views_last_week_log': 0.0,
#     'page_views_last_month_log': 0.0,
#     'page_views_total_log': 3.1699250014423126},
#    'columns_name': [],
#    'columns_field_name': [],
#    'columns_datatype': [],
#    'columns_description': [],
#    'columns_format': [],
#    'download_count': 0,
#    'provenance': 'official',
#    'lens_view_type': 'tabular',
#    'blob_mime_type': None,
#    'hide_from_data_json': False,
#    'publication_date': '2019-10-29T22:41:04.000Z'},
#   'classification': {'categories': [],
#    'tags': [],
#    'domain_category': 'Government',
#    'domain_tags': [],
#    'domain_metadata': []},
#   'metadata': {'domain': 'sandbox.demo.socrata.com'},
#   'permalink': 'https://sandbox.demo.socrata.com/d/ai4n-4yn4',
#   'link': 'https://sandbox.demo.socrata.com/Government/Iowa-Total-Poverty-Rate-and-Children-Living-Under-/ai4n-4yn4',
#   'owner': {'id': 'yuhp-vsb6', 'display_name': 'Goeun Park'}},
#  {'resource': {'name': 'Bridge breakdown by council district',
#    'id': 'tnpe-34ez',
#    'parent_fxf': ['2dep-cf6s'],
#    'description': '',
#    'attribution': None,
#    'attribution_link': None,
#    'contact_email': None,
#    'type': 'chart',
#    'updatedAt': '2019-12-19T15:19:36.000Z',
#    'createdAt': '2019-10-29T17:30:17.000Z',
#    'metadata_updated_at': '2019-12-19T15:12:11.000Z',
#    'data_updated_at': '2019-12-19T15:19:36.000Z',
#    'page_views': {'page_views_last_week': 0,
#     'page_views_last_month': 0,
#     'page_views_total': 8,
#     'page_views_last_week_log': 0.0,
#     'page_views_last_month_log': 0.0,
#     'page_views_total_log': 3.1699250014423126},
#    'columns_name': [],
#    'columns_field_name': [],
#    'columns_datatype': [],
#    'columns_description': [],
#    'columns_format': [],
#    'download_count': 0,
#    'provenance': 'official',
#    'lens_view_type': 'tabular',
#    'blob_mime_type': None,
#    'hide_from_data_json': False,
#    'publication_date': '2019-12-19T15:12:11.000Z'},
#   'classification': {'categories': [],
#    'tags': [],
#    'domain_tags': [],
#    'domain_metadata': []},
#   'metadata': {'domain': 'sandbox.demo.socrata.com'},
#   'permalink': 'https://sandbox.demo.socrata.com/d/tnpe-34ez',
#   'link': 'https://sandbox.demo.socrata.com/dataset/Bridge-breakdown-by-council-district/tnpe-34ez',
#   'owner': {'id': '3fca-ur3r', 'display_name': 'Mathias Burton'}},
#  {'resource': {'name': 'Deputies Involved in More than One Shooting',
#    'id': '38z4-riib',
#    'parent_fxf': ['qbzc-tyub'],
#    'description': 'Information about the deputies involved in shootings',
#    'attribution': 'LA County',
#    'attribution_link': 'https://data.lacounty.gov/Criminal/Deputy-Details-Hit-Shooting-Incidents-and-Non-Hit-/7jc3-gsk7',
#    'contact_email': None,
#    'type': 'chart',
#    'updatedAt': '2019-10-30T15:26:30.000Z',
#    'createdAt': '2019-10-29T18:34:47.000Z',
#    'metadata_updated_at': '2019-10-30T15:26:30.000Z',
#    'data_updated_at': '2019-10-29T18:02:23.000Z',
#    'page_views': {'page_views_last_week': 0,
#     'page_views_last_month': 0,
#     'page_views_total': 8,
#     'page_views_last_week_log': 0.0,
#     'page_views_last_month_log': 0.0,
#     'page_views_total_log': 3.1699250014423126},
#    'columns_name': [],
#    'columns_field_name': [],
#    'columns_datatype': [],
#    'columns_description': [],
#    'columns_format': [],
#    'download_count': None,
#    'provenance': 'official',
#    'lens_view_type': 'tabular',
#    'blob_mime_type': None,
#    'hide_from_data_json': False,
#    'publication_date': '2019-10-30T15:26:29.000Z'},
#   'classification': {'categories': [],
#    'tags': [],
#    'domain_category': 'Public Safety',
#    'domain_tags': [],
#    'domain_metadata': []},
#   'metadata': {'domain': 'sandbox.demo.socrata.com'},
#   'permalink': 'https://sandbox.demo.socrata.com/d/38z4-riib',
#   'link': 'https://sandbox.demo.socrata.com/Public-Safety/Deputies-Involved-in-More-than-One-Shooting/38z4-riib',
#   'owner': {'id': 'eemb-yw39', 'display_name': 'Sally Socrata'}},
#  {'resource': {'name': 'Rail-Related Injuries, Illnesses, and Fatalities',
#    'id': 'j4pc-xdn9',
#    'parent_fxf': ['aig8-7vak'],
#    'description': 'A list of rail related casualties reported via F 6180.55A\nTaken from\nhttps://data.transportation.gov/Railroads/Rail-related-Injuries-Illnesses-Fatalities/6cse-juc3',
#    'attribution': None,
#    'attribution_link': None,
#    'contact_email': None,
#    'type': 'chart',
#    'updatedAt': '2019-10-29T17:33:04.000Z',
#    'createdAt': '2019-10-29T16:24:42.000Z',
#    'metadata_updated_at': '2019-10-29T17:33:04.000Z',
#    'data_updated_at': '2019-10-29T16:00:01.000Z',
#    'page_views': {'page_views_last_week': 0,
#     'page_views_last_month': 0,
#     'page_views_total': 7,
#     'page_views_last_week_log': 0.0,
#     'page_views_last_month_log': 0.0,
#     'page_views_total_log': 3.0},
#    'columns_name': [],
#    'columns_field_name': [],
#    'columns_datatype': [],
#    'columns_description': [],
#    'columns_format': [],
#    'download_count': None,
#    'provenance': 'official',
#    'lens_view_type': 'tabular',
#    'blob_mime_type': None,
#    'hide_from_data_json': False,
#    'publication_date': '2019-10-29T17:33:04.000Z'},
#   'classification': {'categories': ['health', 'environment'],
#    'tags': [],
#    'domain_tags': [],
#    'domain_metadata': []},
#   'metadata': {'domain': 'sandbox.demo.socrata.com'},
#   'permalink': 'https://sandbox.demo.socrata.com/d/j4pc-xdn9',
#   'link': 'https://sandbox.demo.socrata.com/dataset/Rail-Related-Injuries-Illnesses-and-Fatalities/j4pc-xdn9',
#   'owner': {'id': 'rt9e-v5c6', 'display_name': 'Zac Zacal'}},
#  {'resource': {'name': '2017 Bridges',
#    'id': 'pbc5-j9e5',
#    'parent_fxf': ['2dep-cf6s'],
#    'description': '',
#    'attribution': None,
#    'attribution_link': None,
#    'contact_email': None,
#    'type': 'filter',
#    'updatedAt': '2019-12-19T15:19:36.000Z',
#    'createdAt': '2019-10-29T18:07:54.000Z',
#    'metadata_updated_at': '2019-10-29T18:16:59.000Z',
#    'data_updated_at': '2019-12-19T15:19:36.000Z',
#    'page_views': {'page_views_last_week': 0,
#     'page_views_last_month': 0,
#     'page_views_total': 7,
#     'page_views_last_week_log': 0.0,
#     'page_views_last_month_log': 0.0,
#     'page_views_total_log': 3.0},
#    'columns_name': ['BRGUNITID',
#     '2017 SR',
#     'Replacement Value',
#     'SR for reporting',
#     'Deck Area',
#     'Width',
#     'Year Built',
#     'Whole Bridge Count',
#     'Date',
#     'the_geom',
#     '2017 SR for Peds',
#     'SR',
#     'W',
#     'Replacement Value00',
#     'Cond Rating',
#     'Posted?',
#     'SD or FO',
#     '2014 reort SR',
#     'SR for Peds',
#     'NBI SR',
#     'Ped?',
#     'MOVABLE?',
#     'Length',
#     'Design Life',
#     'Bridge Type',
#     'Area',
#     'Count',
#     'Date Built',
#     '2016 SR Reported',
#     'Moveable/RR',
#     'X',
#     '2016 SR for Peds',
#     '2015 NBI SR',
#     '2016 SR',
#     'Council District',
#     'T',
#     'Age Range',
#     'Age',
#     'bridge_name',
#     'bridge_no',
#     'Year'],
#    'columns_field_name': ['brgunitid',
#     '_2017_sr',
#     'replacement_value',
#     'sr_for_reporting',
#     'deck_area',
#     'width',
#     'year_built',
#     'whole_bridge_count',
#     'date',
#     'the_geom',
#     '_2017_sr_for_peds',
#     'sr',
#     'w',
#     'replacement_value00',
#     'cond_rating',
#     'posted',
#     'sd_or_fo',
#     '_2014_reort_sr',
#     'sr_for_peds',
#     'nbi_sr',
#     'ped',
#     'movable',
#     'length',
#     'design_life',
#     'bridge_type',
#     'area',
#     'count',
#     'date_built',
#     '_2016_sr_reported',
#     'moveable_rr',
#     'x',
#     '_2016_sr_for_peds',
#     '_2015_nbi_sr',
#     '_2016_sr',
#     'council_district',
#     't',
#     'age_range',
#     'age',
#     'bridge_name',
#     'bridge_no',
#     'year'],
#    'columns_datatype': ['Text',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Text',
#     'Calendar date',
#     'MultiLine',
#     'Number',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Checkbox',
#     'Text',
#     'Number',
#     'Text',
#     'Text',
#     'Number',
#     'Number',
#     'Calendar date',
#     'Number',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Number',
#     'Text',
#     'Text',
#     'Number'],
#    'columns_description': ['',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     ''],
#    'columns_format': [{},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {}],
#    'download_count': 1,
#    'provenance': 'official',
#    'lens_view_type': 'tabular',
#    'blob_mime_type': None,
#    'hide_from_data_json': False,
# ...
#   'link': 'https://sandbox.demo.socrata.com/Government/Seattle-Council-District-Boundaries/s7g5-ezcw',
#   'owner': {'id': 'eemb-yw39', 'display_name': 'Sally Socrata'}},
#  {'resource': {'name': 'Iowa Farms and Businesses Certified Organic for Crops',
#    'id': '5a7f-drcs',
#    'parent_fxf': None,
#    'description': 'This map displays certified organic farms and businesses physically located in Iowa that were certified for crops. These farms and businesses have successfully passed an inspection from a USDA National Organic Program Accredited Inspection Agency.\n\nFor more information please visit the USDA National Organic Program website: http://www.ams.usda.gov/AMSv1.0/nop',
#    'attribution': None,
#    'attribution_link': 'https://data.iowa.gov/Agriculture/Iowa-Farms-and-Businesses-Certified-Organic-for-Cr/ijnr-psrc',
#    'contact_email': None,
#    'type': 'dataset',
#    'updatedAt': '2019-10-30T18:17:36.000Z',
#    'createdAt': '2019-10-30T18:15:25.000Z',
#    'metadata_updated_at': '2019-10-30T18:17:36.000Z',
#    'data_updated_at': '2019-10-30T18:16:30.000Z',
#    'page_views': {'page_views_last_week': 0,
#     'page_views_last_month': 0,
#     'page_views_total': 1,
#     'page_views_last_week_log': 0.0,
#     'page_views_last_month_log': 0.0,
#     'page_views_total_log': 1.0},
#    'columns_name': ['Record Updated',
#     'Physical Address State',
#     'Physical Address City',
#     'Physical Address Street 1',
#     'HANDLING Effective Date',
#     'WILD CROPS Effective Date',
#     'LIVESTOCK Effective Date',
#     'CROPS Effective Date',
#     'Physical Location',
#     'CROPS Status',
#     'Physical Address Street 2',
#     'Other/Former Names',
#     'Operation ID',
#     'Operation Certification Status Effective Date',
#     'Physical Address ZIP Code',
#     'WILD CROPS Certified Products',
#     'WILD CROPS Status',
#     'Certifier Name',
#     'Operation Name',
#     'HANDLING Certified Products',
#     'HANDLING Status',
#     'LIVESTOCK Certified Products',
#     'LIVESTOCK Status',
#     'CROPS Certified Products',
#     'Operation Certification Status',
#     'LA County Census Tracts'],
#    'columns_field_name': ['record_updated',
#     'physical_address_state',
#     'physical_address_city',
#     'physical_address_street_1',
#     'handling_effective_date',
#     'wild_crops_effective_date',
#     'livestock_effective_date',
#     'crops_effective_date',
#     'physical_location',
#     'crops_status',
#     'physical_address_street_2',
#     'other_former_names',
#     'operation_id',
#     'operation_certification_status_1',
#     'physical_address_zip_code',
#     'wild_crops_certified_products',
#     'wild_crops_status',
#     'certifier_name',
#     'operation_name',
#     'handling_certified_products',
#     'handling_status',
#     'livestock_certified_products',
#     'livestock_status',
#     'crops_certified_products',
#     'operation_certification_status',
#     ':@computed_region_d5up_3ngn'],
#    'columns_datatype': ['Calendar date',
#     'Text',
#     'Text',
#     'Text',
#     'Calendar date',
#     'Calendar date',
#     'Calendar date',
#     'Calendar date',
#     'Point',
#     'Text',
#     'Text',
#     'Text',
#     'Number',
#     'Calendar date',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Text',
#     'Number'],
#    'columns_description': ['',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     ''],
#    'columns_format': [{},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {}],
#    'download_count': None,
#    'provenance': 'official',
#    'lens_view_type': 'tabular',
#    'blob_mime_type': None,
#    'hide_from_data_json': False,
#    'publication_date': '2019-10-30T18:17:36.000Z'},
#   'classification': {'categories': [],
#    'tags': [],
#    'domain_tags': [],
#    'domain_metadata': []},
#   'metadata': {'domain': 'sandbox.demo.socrata.com'},
#   'permalink': 'https://sandbox.demo.socrata.com/d/5a7f-drcs',
#   'link': 'https://sandbox.demo.socrata.com/dataset/Iowa-Farms-and-Businesses-Certified-Organic-for-Cr/5a7f-drcs',
#   'owner': {'id': 'yuhp-vsb6', 'display_name': 'Goeun Park'}},
#  {'resource': {'name': 'Civilian Complaints Against Peace Officers in California',
#    'id': 'kpu2-m4ex',
#    'parent_fxf': None,
#    'description': '',
#    'attribution': None,
#    'attribution_link': None,
#    'contact_email': None,
#    'type': 'dataset',
#    'updatedAt': '2019-10-29T20:17:35.000Z',
#    'createdAt': '2019-10-29T20:14:33.000Z',
#    'metadata_updated_at': '2019-10-29T20:17:35.000Z',
#    'data_updated_at': '2019-10-29T20:17:32.000Z',
#    'page_views': {'page_views_last_week': 0,
#     'page_views_last_month': 0,
#     'page_views_total': 1,
#     'page_views_last_week_log': 0.0,
#     'page_views_last_month_log': 0.0,
#     'page_views_total_log': 1.0},
#    'columns_name': ['GenderExonerated',
#     'GenderSustained',
#     'NonCriminalInDetentionSustained',
#     'TotalRacialProfilingComplaintsPending',
#     'NonCriminalInDetentionPending',
#     'NonCriminalPending',
#     'PhysicalDisabilityUnfounded',
#     'ReligionUnfounded',
#     'RaceEthnicityUnfounded',
#     'GenderUnfounded',
#     'TotalRacialProfilingComplaintsUnfounded',
#     'NonCriminalInDetentionUnfounded',
#     'GenderNotSustained',
#     'RaceEthnicityNotSustained',
#     'MisdemeanorInDetentionNotSustained',
#     'ReligionNotSustained',
#     'TotalComplaintsInDetentionNotSustained',
#     'FelonyNotSustained',
#     'PhysicalDisabilityExonerated',
#     'MisdemeanorInDetentionExonerated',
#     'TotalRacialProfilingComplaintsExonerated',
#     'NonCriminalExonerated',
#     'GenderIdentityExpressionSustained',
#     'FelonySustained',
#     'MisdemeanorNotSustained',
#     'TotalComplaintsSustained',
#     'GenderReported',
#     'NationalityReported',
#     'TotalComplaintsInDetentionReported',
#     'AgeReported',
#     'AgencyName',
#     'MentalDisabilityPending',
#     'NationalityPending',
#     'RaceEthnicityPending',
#     'FelonyInDetentionPending',
#     'TotalRacialProfilingComplaintsReported',
#     'MisdemeanorInDetentionPending',
#     'NonCriminalReported',
#     'FelonyUnfounded',
#     'MisdemeanorReported',
#     'NonCriminalUnfounded',
#     'FelonyInDetentionSustained',
#     'TotalRacialProfilingComplaintsNotSustained',
#     'ReligionReported',
#     'GenderPending',
#     'AgeExonerated',
#     'SexualOrientationExonerated',
#     'GenderIdentityExpressionExonerated',
#     'NonCriminalInDetentionExonerated',
#     'GenderIdentityExpressionReported',
#     'FelonyInDetentionReported',
#     'NonCriminalInDetentionReported',
#     'ComplaintYear',
#     'ReligionExonerated',
#     'AgeSustained',
#     'GenderIdentityExpressionNotSustained',
#     'TotalComplaintsInDetentionSustained',
#     'TotalRacialProfilingComplaintsSustained',
#     'TotalComplaintsInDetentionPending',
#     'TotalComplaintsPending',
#     'MentalDisabilityUnfounded',
#     'FelonyInDetentionUnfounded',
#     'NonCriminalNotSustained',
#     'TotalComplaintsNotSustained',
#     'RaceEthnicityExonerated',
#     'FelonyExonerated',
#     'PhysicalDisabilitySustained',
#     'NationalitySustained',
#     'MisdemeanorSustained',
#     'MentalDisabilityReported',
#     'TotalComplaintsReported',
#     'RaceEthnicityReported',
#     'NCIC',
#     'NationalityUnfounded',
#     'TotalComplaintsInDetentionUnfounded',
#     'FelonyInDetentionNotSustained',
#     'MisdemeanorPending',
#     'TotalComplaintsUnfounded',
#     'PhysicalDisabilityPending',
#     'SexualOrientationPending',
#     'AgePending',
#     'FelonyPending',
#     'SexualOrientationUnfounded',
#     'GenderIdentityExpressionUnfounded',
#     'PhysicalDisabilityNotSustained',
#     'TotalComplaintsExonerated',
#     'ReligionSustained',
#     'RaceEthnicitySustained',
#     'MisdemeanorInDetentionReported',
#     'FelonyReported',
#     'GenderIdentityExpressionPending',
#     'AgeUnfounded',
#     'MisdemeanorUnfounded',
#     'MentalDisabilityNotSustained',
#     'SexualOrientationNotSustained',
#     'AgeNotSustained',
#     'NationalityNotSustained',
#     'TotalComplaintsInDetentionExonerated',
#     'MisdemeanorExonerated',
#     'MentalDisabilitySustained',
#     'SexualOrientationSustained',
#     'MisdemeanorInDetentionSustained',
#     'NonCriminalSustained',
#     'SexualOrientationReported',
#     'ReligionPending',
#     'MisdemeanorInDetentionUnfounded',
#     'MentalDisabilityExonerated',
#     'NonCriminalInDetentionNotSustained',
#     'FelonyInDetentionExonerated',
#     'NationalityExonerated',
#     'NoComplaintsFiled',
#     'PhysicalDisabilityReported'],
#    'columns_field_name': ['genderexonerated',
#     'gendersustained',
#     'noncriminalindetentionsu',
#     'totalracialprofilingcomp_5',
#     'noncriminalindetentionpending',
#     'noncriminalpending',
#     'physicaldisabilityunfounded',
#     'religionunfounded',
#     'raceethnicityunfounded',
#     'genderunfounded',
#     'totalracialprofilingcomp_4',
#     'noncriminalindetentionun',
#     'gendernotsustained',
#     'raceethnicitynotsustained',
#     'misdemeanorindetentionno',
#     'religionnotsustained',
#     'totalcomplaintsindetenti_3',
#     'felonynotsustained',
#     'physicaldisabilityexonerated',
#     'misdemeanorindetentionex',
#     'totalracialprofilingcomp_2',
#     'noncriminalexonerated',
#     'genderidentityexpression_1',
#     'felonysustained',
#     'misdemeanornotsustained',
#     'totalcomplaintssustained',
#     'genderreported',
#     'nationalityreported',
#     'totalcomplaintsindetenti',
#     'agereported',
#     'agencyname',
#     'mentaldisabilitypending',
#     'nationalitypending',
#     'raceethnicitypending',
#     'felonyindetentionpending',
#     'totalracialprofilingcomp',
#     'misdemeanorindetentionpending',
#     'noncriminalreported',
#     'felonyunfounded',
#     'misdemeanorreported',
#     'noncriminalunfounded',
#     'felonyindetentionsustained',
#     'totalracialprofilingcomp_3',
#     'religionreported',
#     'genderpending',
#     'ageexonerated',
#     'sexualorientationexonerated',
#     'genderidentityexpression_2',
#     'noncriminalindetentionex',
#     'genderidentityexpression',
#     'felonyindetentionreported',
#     'noncriminalindetentionreported',
#     'complaintyear',
#     'religionexonerated',
#     'agesustained',
#     'genderidentityexpression_3',
#     'totalcomplaintsindetenti_1',
#     'totalracialprofilingcomp_1',
#     'totalcomplaintsindetenti_5',
#     'totalcomplaintspending',
#     'mentaldisabilityunfounded',
#     'felonyindetentionunfounded',
#     'noncriminalnotsustained',
#     'totalcomplaintsnotsustained',
#     'raceethnicityexonerated',
#     'felonyexonerated',
#     'physicaldisabilitysustained',
#     'nationalitysustained',
#     'misdemeanorsustained',
#     'mentaldisabilityreported',
#     'totalcomplaintsreported',
#     'raceethnicityreported',
#     'ncic',
#     'nationalityunfounded',
#     'totalcomplaintsindetenti_4',
#     'felonyindetentionnotsustained',
#     'misdemeanorpending',
#     'totalcomplaintsunfounded',
#     'physicaldisabilitypending',
#     'sexualorientationpending',
#     'agepending',
#     'felonypending',
#     'sexualorientationunfounded',
#     'genderidentityexpression_4',
#     'physicaldisabilitynotsustained',
#     'totalcomplaintsexonerated',
#     'religionsustained',
#     'raceethnicitysustained',
#     'misdemeanorindetentionreported',
#     'felonyreported',
#     'genderidentityexpression_5',
#     'ageunfounded',
#     'misdemeanorunfounded',
#     'mentaldisabilitynotsustained',
#     'sexualorientationnotsustained',
#     'agenotsustained',
#     'nationalitynotsustained',
#     'totalcomplaintsindetenti_2',
#     'misdemeanorexonerated',
#     'mentaldisabilitysustained',
#     'sexualorientationsustained',
#     'misdemeanorindetentionsu',
#     'noncriminalsustained',
#     'sexualorientationreported',
#     'religionpending',
#     'misdemeanorindetentionun',
#     'mentaldisabilityexonerated',
#     'noncriminalindetentionno',
#     'felonyindetentionexonerated',
#     'nationalityexonerated',
#     'nocomplaintsfiled',
#     'physicaldisabilityreported'],
#    'columns_datatype': ['Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Text',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Text',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Text',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Number',
#     'Checkbox',
#     'Number'],
#    'columns_description': ['',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     ''],
#    'columns_format': [{},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {},
#     {}],
#    'download_count': None,
#    'provenance': 'official',
#    'lens_view_type': 'tabular',
#    'blob_mime_type': None,
#    'hide_from_data_json': False,
#    'publication_date': '2019-10-29T20:17:35.000Z'},
#   'classification': {'categories': ['politics'],
#    'tags': [],
#    'domain_tags': [],
#    'domain_metadata': []},
#   'metadata': {'domain': 'sandbox.demo.socrata.com'},
#   'permalink': 'https://sandbox.demo.socrata.com/d/kpu2-m4ex',
#   'link': 'https://sandbox.demo.socrata.com/dataset/Civilian-Complaints-Against-Peace-Officers-in-Cali/kpu2-m4ex',
#   'owner': {'id': 'eemb-yw39', 'display_name': 'Sally Socrata'}}]

# %%
from urllib3 import Request
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-50426861d04e> in <module>
# ----> 1 from urllib3 import Request
#
# ImportError: cannot import name 'Request' from 'urllib3' (/Applications/anaconda3/envs/fintech/lib/python3.7/site-packages/urllib3/__init__.py)

# %%
client.update_metadata("nimj-3ivp", {"attributionLink": "https://anothertest.com"})
{"newBackend": false, "licenseId": "CC0_10", "publicationDate": 1436655117, "viewLastModified": 1451289003, "owner": {"roleName": "administrator", "rights": [], "displayName": "Brett", "id": "cdqe-xcn5", "screenName": "Brett"}, "query": {}, "id": "songs", "createdAt": 1398014181, "category": "Public Safety", "publicationAppendEnabled": true, "publicationStage": "published", "rowsUpdatedBy": "cdqe-xcn5", "publicationGroup": 1552205, "displayType": "table", "state": "normal", "attributionLink": "https://anothertest.com", "tableId": 3523378, "columns": [], "metadata": {"rdfSubject": "0", "renderTypeConfig": {"visible": {"table": true}}, "availableDisplayTypes": ["table", "fatrow", "page"], "attachments": ... }}
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-10-fe4f2dd1d5f4> in <module>
# ----> 1 client.update_metadata("nimj-3ivp", {"attributionLink": "https://anothertest.com"})
#       2 {"newBackend": false, "licenseId": "CC0_10", "publicationDate": 1436655117, "viewLastModified": 1451289003, "owner": {"roleName": "administrator", "rights": [], "displayName": "Brett", "id": "cdqe-xcn5", "screenName": "Brett"}, "query": {}, "id": "songs", "createdAt": 1398014181, "category": "Public Safety", "publicationAppendEnabled": true, "publicationStage": "published", "rowsUpdatedBy": "cdqe-xcn5", "publicationGroup": 1552205, "displayType": "table", "state": "normal", "attributionLink": "https://anothertest.com", "tableId": 3523378, "columns": [], "metadata": {"rdfSubject": "0", "renderTypeConfig": {"visible": {"table": true}}, "availableDisplayTypes": ["table", "fatrow", "page"], "attachments": ... }}
#
# /Applications/anaconda3/envs/fintech/lib/python3.7/site-packages/sodapy/__init__.py in update_metadata(self, dataset_identifier, update_fields, content_type)
#     259         '''
#     260         resource = _format_old_api_request(dataid=dataset_identifier, content_type=content_type)
# --> 261         return self._perform_update("put", resource, update_fields)
#     262
#     263     def download_attachments(self, dataset_identifier, content_type="json",
#
# /Applications/anaconda3/envs/fintech/lib/python3.7/site-packages/sodapy/__init__.py in _perform_update(self, method, resource, payload)
#     416         if isinstance(payload, (dict, list)):
#     417             response = self._perform_request(method, resource,
# --> 418                                              data=json.dumps(payload))
#     419         elif isinstance(payload, IOBase):
#     420             headers = {
#
# /Applications/anaconda3/envs/fintech/lib/python3.7/site-packages/sodapy/__init__.py in _perform_request(self, request_type, resource, **kwargs)
#     463         # handle errors
#     464         if response.status_code not in (200, 202):
# --> 465             _raise_for_status(response)
#     466
#     467         # when responses have no content body (ie. delete, set_permission),
#
# /Applications/anaconda3/envs/fintech/lib/python3.7/site-packages/sodapy/__init__.py in _raise_for_status(response)
#     517         if more_info and more_info.lower() != response.reason.lower():
#     518             http_error_msg += ".\n\t{0}".format(more_info)
# --> 519         raise requests.exceptions.HTTPError(http_error_msg, response=response)
#     520
#     521
#
# HTTPError: 403 Client Error: Forbidden.
# 	Invalid app_token specified
